# %%
import pandas as pd
from sqlalchemy import create_engine

# %%
title_file = "Resources/ImdbTitleBasics.csv"
title_df = pd.read_csv(title_file)
title_df.tail()
# Out:
# /Users/rachelthorpe/opt/anaconda3/lib/python3.8/site-packages/IPython/core/interactiveshell.py:3146: DtypeWarning: Columns (5) have mixed types.Specify dtype option on import or set low_memory=False.
#   has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
#              tconst  titleType                         primaryTitle  \
# 1048570  tt10140376   tvSeries                      Começar do Zero
# 1048571  tt10140378  tvEpisode                           Corey Hart
# 1048572   tt1014037  tvEpisode                               Escape
# 1048573  tt10140380      short                         Fear of Dogs
# 1048574  tt10140382  tvEpisode  Wondercon Anaheim 2019 (Highlights)
#
#                                originalTitle  isAdult startYear endYear  \
# 1048570                      Começar do Zero        0      2019      \N
# 1048571                           Corey Hart        0      2019      \N
# 1048572                               Escape        0      2008      \N
# 1048573                         Fear of Dogs        0      1994      \N
# 1048574  Wondercon Anaheim 2019 (Highlights)        0      2019      \N
#
#         runtimeMinutes       genres
# 1048570             90   Reality-TV
# 1048571             \N    Talk-Show
# 1048572             29  Documentary
# 1048573             \N  Drama,Short
# 1048574             \N        Music

# %%
ratings_file = "Resources/ImdbTitleRatings.csv"
ratings_df = pd.read_csv(ratings_file)
ratings_df.tail()
# Out:
#             tconst  averageRating  numVotes
# 1048570  tt7512616            9.0         5
# 1048571  tt7512624            5.5       931
# 1048572  tt7512632            3.4        33
# 1048573  tt7512636            6.4        22
# 1048574  tt7512670            7.0        49

# %%
title_df
# Out:
#              tconst  titleType                         primaryTitle  \
# 0         tt0000001      short                           Carmencita
# 1         tt0000002      short               Le clown et ses chiens
# 2         tt0000003      short                       Pauvre Pierrot
# 3         tt0000004      short                          Un bon bock
# 4         tt0000005      short                     Blacksmith Scene
# ...             ...        ...                                  ...
# 1048570  tt10140376   tvSeries                      Começar do Zero
# 1048571  tt10140378  tvEpisode                           Corey Hart
# 1048572   tt1014037  tvEpisode                               Escape
# 1048573  tt10140380      short                         Fear of Dogs
# 1048574  tt10140382  tvEpisode  Wondercon Anaheim 2019 (Highlights)
#
#                                originalTitle  isAdult startYear endYear  \
# 0                                 Carmencita        0      1894      \N
# 1                     Le clown et ses chiens        0      1892      \N
# 2                             Pauvre Pierrot        0      1892      \N
# 3                                Un bon bock        0      1892      \N
# 4                           Blacksmith Scene        0      1893      \N
# ...                                      ...      ...       ...     ...
# 1048570                      Começar do Zero        0      2019      \N
# 1048571                           Corey Hart        0      2019      \N
# 1048572                               Escape        0      2008      \N
# 1048573                         Fear of Dogs        0      1994      \N
# 1048574  Wondercon Anaheim 2019 (Highlights)        0      2019      \N
#
#         runtimeMinutes                    genres
# 0                    1         Documentary,Short
# 1                    5           Animation,Short
# 2                    4  Animation,Comedy,Romance
# 3                   12           Animation,Short
# 4                    1              Comedy,Short
# ...                ...                       ...
# 1048570             90                Reality-TV
# 1048571             \N                 Talk-Show
# 1048572             29               Documentary
# 1048573             \N               Drama,Short
# 1048574             \N                     Music
#
# [1048575 rows x 9 columns]

# %%
title_df['tconst'] = title_df['tconst'].str[2:]
title_df

# %%
title_df['tconst'] = title_df['tconst'].astype(int)
title_df
# Out:
#            tconst  titleType                         primaryTitle  \
# 0               1      short                           Carmencita
# 1               2      short               Le clown et ses chiens
# 2               3      short                       Pauvre Pierrot
# 3               4      short                          Un bon bock
# 4               5      short                     Blacksmith Scene
# ...           ...        ...                                  ...
# 1048570  10140376   tvSeries                      Começar do Zero
# 1048571  10140378  tvEpisode                           Corey Hart
# 1048572   1014037  tvEpisode                               Escape
# 1048573  10140380      short                         Fear of Dogs
# 1048574  10140382  tvEpisode  Wondercon Anaheim 2019 (Highlights)
#
#                                originalTitle  isAdult startYear endYear  \
# 0                                 Carmencita        0      1894      \N
# 1                     Le clown et ses chiens        0      1892      \N
# 2                             Pauvre Pierrot        0      1892      \N
# 3                                Un bon bock        0      1892      \N
# 4                           Blacksmith Scene        0      1893      \N
# ...                                      ...      ...       ...     ...
# 1048570                      Começar do Zero        0      2019      \N
# 1048571                           Corey Hart        0      2019      \N
# 1048572                               Escape        0      2008      \N
# 1048573                         Fear of Dogs        0      1994      \N
# 1048574  Wondercon Anaheim 2019 (Highlights)        0      2019      \N
#
#         runtimeMinutes                    genres
# 0                    1         Documentary,Short
# 1                    5           Animation,Short
# 2                    4  Animation,Comedy,Romance
# 3                   12           Animation,Short
# 4                    1              Comedy,Short
# ...                ...                       ...
# 1048570             90                Reality-TV
# 1048571             \N                 Talk-Show
# 1048572             29               Documentary
# 1048573             \N               Drama,Short
# 1048574             \N                     Music
#
# [1048575 rows x 9 columns]

# %%
ratings_df['tconst']=ratings_df['tconst'].str[2:].astype(int)
ratings_df
# Out:
#           tconst  averageRating  numVotes
# 0              1            5.6      1694
# 1              2            6.0       210
# 2              3            6.5      1441
# 3              4            6.1       122
# 4              5            6.1      2240
# ...          ...            ...       ...
# 1048570  7512616            9.0         5
# 1048571  7512624            5.5       931
# 1048572  7512632            3.4        33
# 1048573  7512636            6.4        22
# 1048574  7512670            7.0        49
#
# [1048575 rows x 3 columns]

# %%
title_df_renamed = title_df.rename(columns={"tconst":"id"})
title_df_renamed
# Out:
#                id  titleType                         primaryTitle  \
# 0               1      short                           Carmencita
# 1               2      short               Le clown et ses chiens
# 2               3      short                       Pauvre Pierrot
# 3               4      short                          Un bon bock
# 4               5      short                     Blacksmith Scene
# ...           ...        ...                                  ...
# 1048570  10140376   tvSeries                      Começar do Zero
# 1048571  10140378  tvEpisode                           Corey Hart
# 1048572   1014037  tvEpisode                               Escape
# 1048573  10140380      short                         Fear of Dogs
# 1048574  10140382  tvEpisode  Wondercon Anaheim 2019 (Highlights)
#
#                                originalTitle  isAdult startYear endYear  \
# 0                                 Carmencita        0      1894      \N
# 1                     Le clown et ses chiens        0      1892      \N
# 2                             Pauvre Pierrot        0      1892      \N
# 3                                Un bon bock        0      1892      \N
# 4                           Blacksmith Scene        0      1893      \N
# ...                                      ...      ...       ...     ...
# 1048570                      Começar do Zero        0      2019      \N
# 1048571                           Corey Hart        0      2019      \N
# 1048572                               Escape        0      2008      \N
# 1048573                         Fear of Dogs        0      1994      \N
# 1048574  Wondercon Anaheim 2019 (Highlights)        0      2019      \N
#
#         runtimeMinutes                    genres
# 0                    1         Documentary,Short
# 1                    5           Animation,Short
# 2                    4  Animation,Comedy,Romance
# 3                   12           Animation,Short
# 4                    1              Comedy,Short
# ...                ...                       ...
# 1048570             90                Reality-TV
# 1048571             \N                 Talk-Show
# 1048572             29               Documentary
# 1048573             \N               Drama,Short
# 1048574             \N                     Music
#
# [1048575 rows x 9 columns]

# %%
ratings_df_renamed = ratings_df.rename(columns={"tconst":"id"})
ratings_df_renamed
# Out:
#               id  averageRating  numVotes
# 0              1            5.6      1694
# 1              2            6.0       210
# 2              3            6.5      1441
# 3              4            6.1       122
# 4              5            6.1      2240
# ...          ...            ...       ...
# 1048570  7512616            9.0         5
# 1048571  7512624            5.5       931
# 1048572  7512632            3.4        33
# 1048573  7512636            6.4        22
# 1048574  7512670            7.0        49
#
# [1048575 rows x 3 columns]

# %%
title_df_clean = title_df_renamed.drop(columns=["endYear", "isAdult"])
title_df_clean
# Out:
#                id  titleType                         primaryTitle  \
# 0               1      short                           Carmencita
# 1               2      short               Le clown et ses chiens
# 2               3      short                       Pauvre Pierrot
# 3               4      short                          Un bon bock
# 4               5      short                     Blacksmith Scene
# ...           ...        ...                                  ...
# 1048570  10140376   tvSeries                      Começar do Zero
# 1048571  10140378  tvEpisode                           Corey Hart
# 1048572   1014037  tvEpisode                               Escape
# 1048573  10140380      short                         Fear of Dogs
# 1048574  10140382  tvEpisode  Wondercon Anaheim 2019 (Highlights)
#
#                                originalTitle startYear runtimeMinutes  \
# 0                                 Carmencita      1894              1
# 1                     Le clown et ses chiens      1892              5
# 2                             Pauvre Pierrot      1892              4
# 3                                Un bon bock      1892             12
# 4                           Blacksmith Scene      1893              1
# ...                                      ...       ...            ...
# 1048570                      Começar do Zero      2019             90
# 1048571                           Corey Hart      2019             \N
# 1048572                               Escape      2008             29
# 1048573                         Fear of Dogs      1994             \N
# 1048574  Wondercon Anaheim 2019 (Highlights)      2019             \N
#
#                            genres
# 0               Documentary,Short
# 1                 Animation,Short
# 2        Animation,Comedy,Romance
# 3                 Animation,Short
# 4                    Comedy,Short
# ...                           ...
# 1048570                Reality-TV
# 1048571                 Talk-Show
# 1048572               Documentary
# 1048573               Drama,Short
# 1048574                     Music
#
# [1048575 rows x 7 columns]

# %%
title_df_clean = title_df_clean['titleType','primaryTitle', 'originalTitle', 'startYear', 'runtimeMinutes'].str.lower()
title_df_clean
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~/opt/anaconda3/lib/python3.8/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    2894             try:
# -> 2895                 return self._engine.get_loc(casted_key)
#    2896             except KeyError as err:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: ('titleType', 'primaryTitle', 'originalTitle', 'startYear', 'runtimeMinutes')
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-14-d5a47f4fb603> in <module>
# ----> 1 title_df_clean = title_df_clean['titleType','primaryTitle', 'originalTitle', 'startYear', 'runtimeMinutes'].str.lower()
#       2 title_df_clean
#
# ~/opt/anaconda3/lib/python3.8/site-packages/pandas/core/frame.py in __getitem__(self, key)
#    2900             if self.columns.nlevels > 1:
#    2901                 return self._getitem_multilevel(key)
# -> 2902             indexer = self.columns.get_loc(key)
#    2903             if is_integer(indexer):
#    2904                 indexer = [indexer]
#
# ~/opt/anaconda3/lib/python3.8/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    2895                 return self._engine.get_loc(casted_key)
#    2896             except KeyError as err:
# -> 2897                 raise KeyError(key) from err
#    2898
#    2899         if tolerance is not None:
#
# KeyError: ('titleType', 'primaryTitle', 'originalTitle', 'startYear', 'runtimeMinutes')
